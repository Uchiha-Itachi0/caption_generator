# %%
API_TOKEN="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"
import requests

API_URL = "https://api-inference.huggingface.co/models/Salesforce/blip-image-captioning-large"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

semantic = query("./assets/images/image-2.jpg")[0]['generated_text']
semantic
# Out:
# 'there is a man standing on a beach with a skateboard'

# %%
API_URL = "https://api-inference.huggingface.co/models/mistralai/Mixtral-8x7B-Instruct-v0.1"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
captions = query({
	"inputs": f'Question: Write a 3 nice caption for instagram using this semantic from the image {semantic} Answer: ',
})
captions
# Out:
# [{'generated_text': 'Question: Write a 3 nice caption for instagram using this semantic from the image there is a man standing on a beach with a skateboard Answer: 1. "Catching waves and riding ramps - the beauty of being by the beach with a skateboard. 🌊🛹 #BeachLife #Skateboarding"\n2. "Embracing the beach vibes and showcasing some cool tricks on the board. 🤙🌞 #SkateboardingOnTheBeach"\n3. "Savor the ocean breeze and the thrill of'}]

# %%
from IPython.display import Image
Image("anubhav.png", height = 720, width=300)
